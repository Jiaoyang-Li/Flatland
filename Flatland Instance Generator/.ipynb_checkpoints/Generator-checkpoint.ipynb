# %%
from flatland.envs.rail_env import RailEnv
from flatland.envs.rail_generators import sparse_rail_generator
from flatland.envs.schedule_generators import sparse_schedule_generator
from flatland.envs.malfunction_generators import malfunction_from_params,MalfunctionParameters
from flatland.utils.rendertools import RenderTool, AgentRenderVariant
from PIL import Image  
import PIL
import os

# %%
generate_how_many = 400
image_folder = "./image/"
instance_folder = "./pkl/"

# change this number to match test0 test1 test2 etc.
test_num = 0

#####################################################################
# local env parameters
#####################################################################
x_dim = 30
y_dim = 30

# parameters to sparse_rail_genertor
max_num_stations = 3
given_max_rails_between_cities = 2 # not clear what this does
given_max_rails_in_city = 3 # not clear what this does
given_num_agents = 10

# speed profile, 1 -> speed is 1, 1_2 -> speed 0.5, 1_3 -> speed 1/3, etc. sum has to be 1
given_1_speed_train_percentage = 1
given_1_2_speed_train_percentage = 0
given_1_3_speed_train_percentage = 0
given_1_4_speed_train_percentage = 0

# malfunction parameters
malfunction_rate = 0.4          # fraction number, probability of having a stop.
min_duration = 3
max_duration = 20

# random seed list
seed_list = range(0,500)

# %%
counter = 0

while(counter<generate_how_many):


    stochastic_data = MalfunctionParameters(
                                            malfunction_rate=malfunction_rate,  # Rate of malfunction occurence
                                            min_duration=min_duration,  # Minimal duration of malfunction
                                            max_duration=max_duration  # Max duration of malfunction
                                            )

    # Different agent types (trains) with different speeds.
    # the number [0,1] means the percentage of trains with the corresponding movement speed.
    speed_ration_map = {1.: given_1_speed_train_percentage,  # Fast passenger train
                        1. / 2.: given_1_2_speed_train_percentage,  # Fast freight train
                        1. / 3.: given_1_3_speed_train_percentage,  # Slow commuter train
                        1. / 4.: given_1_4_speed_train_percentage}  # Slow freight train



    local_env = RailEnv(width=x_dim,
                  height=y_dim,
                  rail_generator=sparse_rail_generator(max_num_cities=max_num_stations,
                                                       # Number of cities in map (where train stations are)
                                                       grid_mode=False,
                                                       max_rails_between_cities=given_max_rails_between_cities,
                                                       max_rails_in_city=given_max_rails_in_city,
                                                       ),
                  schedule_generator=sparse_schedule_generator(speed_ration_map),
                  number_of_agents=given_num_agents,
                  malfunction_generator_and_process_data=malfunction_from_params(stochastic_data),
                  remove_agents_at_target=True,
                  record_steps=True,
                  random_seed = seed_list[counter]
                  )

    local_env.reset()
    env_renderer = RenderTool(local_env, gl="PGL")
    env_renderer.render_env()
    
    test_instance_folder = instance_folder+"test"+str(test_num)+"/"
    test_image_folder = image_folder+"test"+str(test_num)+"/"
    
    # create folder if not exist
    if not os.path.exists(test_instance_folder):
        os.makedirs(test_instance_folder)
    
    
    #save the instance to pkl file
    local_env.save(instance_folder+"test"+str(test_num)+"_"+str(counter)+".pkl")
    
    #save the image of the generated instance
    image = env_renderer.get_image()
    pil_image = PIL.Image.fromarray(image)
    display(pil_image)
    pil_image.save(image_folder+"test"+str(test_num)+"_"+str(counter)+".png")
    
    
    counter+= 1
# Out:
# deprecated call to env.save() - pls call RailEnvPersister.save()
# C:\Anaconda\lib\site-packages\flatland\utils\rendertools.py:396: UserWarning: Predictor did not provide any predicted cells to render.                 Observation builder needs to populate: env.dev_obs_dict
#   Observation builder needs to populate: env.dev_obs_dict")
# <PIL.Image.Image image mode=RGBA size=484x484 at 0x22239B256C8>
# deprecated call to env.save() - pls call RailEnvPersister.save()
# <PIL.Image.Image image mode=RGBA size=484x484 at 0x2223CAD4348>
# deprecated call to env.save() - pls call RailEnvPersister.save()
# <PIL.Image.Image image mode=RGBA size=484x484 at 0x222459A26C8>
# deprecated call to env.save() - pls call RailEnvPersister.save()
# <PIL.Image.Image image mode=RGBA size=484x484 at 0x22239AFE6C8>
# deprecated call to env.save() - pls call RailEnvPersister.save()
# <PIL.Image.Image image mode=RGBA size=484x484 at 0x2224991CAC8>
# deprecated call to env.save() - pls call RailEnvPersister.save()
# <PIL.Image.Image image mode=RGBA size=484x484 at 0x2224597E888>
# deprecated call to env.save() - pls call RailEnvPersister.save()
# <PIL.Image.Image image mode=RGBA size=484x484 at 0x2224991DE48>
# deprecated call to env.save() - pls call RailEnvPersister.save()
# <PIL.Image.Image image mode=RGBA size=484x484 at 0x2223CAB4288>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55     try:
# ---> 56         return getattr(obj, method)(*args, **kwds)
#      57
#
# AttributeError: 'tuple' object has no attribute 'transpose'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-3fd1ea2b79fd> in <module>
#      35                   )
#      36
# ---> 37     local_env.reset()
#      38     env_renderer = RenderTool(local_env, gl="PGL")
#      39     env_renderer.render_env()
#
# C:\Anaconda\lib\site-packages\flatland\envs\rail_env.py in reset(self, regenerate_rail, regenerate_schedule, activate_agents, random_seed)
#     317         if regenerate_rail or self.rail is None:
#     318             rail, optionals = self.rail_generator(self.width, self.height, self.number_of_agents, self.num_resets,
# --> 319                                                   self.np_random)
#     320
#     321             self.rail = rail
#
# C:\Anaconda\lib\site-packages\flatland\envs\rail_generators.py in generator(width, height, num_agents, num_resets, np_random)
#     670
#     671         # Fix all transition elements
# --> 672         _fix_transitions(city_cells, inter_city_lines, grid_map, vector_field)
#     673
#     674         return grid_map, {'agents_hints': {
#
# C:\Anaconda\lib\site-packages\flatland\envs\rail_generators.py in _fix_transitions(city_cells, inter_city_lines, grid_map, vector_field)
#    1106         cells_to_fix = city_cells + inter_city_lines
#    1107         for cell in cells_to_fix:
# -> 1108             cell_valid = grid_map.cell_neighbours_valid(cell, True)
#    1109
#    1110             if not cell_valid:
#
# C:\Anaconda\lib\site-packages\flatland\core\transition_map.py in cell_neighbours_valid(self, rcPos, check_this_cell)
#     411         g2binTrans = np.unpackbits(lnBinTrans).reshape(4, 4)  # 4x4 x uint8 binary(0,1)
#     412         gDirOut = g2binTrans.any(axis=0)  # outbound directions as boolean array (4)
# --> 413         giDirOut = np.argwhere(gDirOut)[:, 0]  # valid outbound directions as array of int
#     414
#     415         # loop over available outbound directions (indices) for rcPos
#
# C:\Anaconda\lib\site-packages\numpy\core\numeric.py in argwhere(a)
#     879
#     880     """
# --> 881     return transpose(nonzero(a))
#     882
#     883
#
# C:\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in transpose(a, axes)
#     637
#     638     """
# --> 639     return _wrapfunc(a, 'transpose', axes)
#     640
#     641
#
# C:\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      64     # a downstream library like 'pandas'.
#      65     except (AttributeError, TypeError):
# ---> 66         return _wrapit(obj, method, *args, **kwds)
#      67
#      68
#
# C:\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      44     except AttributeError:
#      45         wrap = None
# ---> 46     result = getattr(asarray(obj), method)(*args, **kwds)
#      47     if wrap:
#      48         if not isinstance(result, mu.ndarray):
#
# C:\Anaconda\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# KeyboardInterrupt:
